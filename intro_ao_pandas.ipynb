# %% [markdown]
# <a href="https://colab.research.google.com/github/drdhenrique/estudos/blob/main/intro_ao_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pandas

# %%
import pandas as pd

# %%
df_acoes = pd.read_csv("https://raw.githubusercontent.com/drdhenrique/datasets/main/BBAS3.SA.csv")

# %%
df.shape
# Out:
# (249, 7)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Date"])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2022-09-19  39.009998  40.380001  38.299999  40.180000  36.829857  15929500
# 1  2022-09-20  40.299999  40.970001  40.160000  40.790001  37.388992  17350700
# 2  2022-09-21  40.970001  41.049999  40.270000  40.500000  37.123169  12284500
# 3  2022-09-22  40.750000  41.430000  40.090000  41.240002  37.801476  14399000
# 4  2022-09-23  40.799999  40.900002  40.080002  40.730000  37.333992  17071200

# %%
df.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 244  2023-09-11  47.080002  47.540001  46.840000  47.380001  47.045803
# 245  2023-09-12  47.189999  47.619999  47.090000  47.299999  47.299999
# 246  2023-09-13  47.349998  47.900002  47.130001  47.259998  47.259998
# 247  2023-09-14  47.490002  47.919998  47.189999  47.389999  47.389999
# 248  2023-09-15  47.419998  47.700001  47.110001  47.549999  47.549999
#
#        Volume
# 244   7199900
# 245   7685200
# 246   7362800
# 247   7284900
# 248  10803000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df["High"].head()
# Out:
# 0    40.380001
# 1    40.970001
# 2    41.049999
# 3    41.430000
# 4    40.900002
# Name: High, dtype: float64

# %%
df["High"].mean()
# Out:
# 42.232369502008034

# %% [markdown]
# # Criando DataFrames

# %%
dados = {
    'nome': ['Carlos', 'Pedro', 'Daniela', 'Fernanda'],
    'idade': [35, 32, 15, 49],
    'cidade': ['Araraquara', 'Belém', 'Natal', 'Curitiba'],
    'comprou': [True, False, False, True]
}


df = pd.DataFrame(dados)

df
# Out:
#        nome  idade      cidade  comprou
# 0    Carlos     35  Araraquara     True
# 1     Pedro     32       Belém    False
# 2   Daniela     15       Natal    False
# 3  Fernanda     49    Curitiba     True

# %%
nome = ['Carlos', 'Pedro', 'Daniela', 'Fernanda']
idade =  [35, 32, 15, 49]
cidade = ['Araraquara', 'Belém', 'Natal', 'Curitiba']
compras = [True, False, False, True]

labels = ['nome', 'idade', 'cidade', 'comprou']
list_cols = [nome, idade, cidade, compras]

dados = dict(list(zip(labels, list_cols)))

df1 = pd.DataFrame(dados)

df1
# Out:
#        nome  idade      cidade  comprou
# 0    Carlos     35  Araraquara     True
# 1     Pedro     32       Belém    False
# 2   Daniela     15       Natal    False
# 3  Fernanda     49    Curitiba     True

# %%
df['saldo'] = 0.0

df
# Out:
#        nome  idade      cidade  comprou  saldo
# 0    Carlos     35  Araraquara     True    0.0
# 1     Pedro     32       Belém    False    0.0
# 2   Daniela     15       Natal    False    0.0
# 3  Fernanda     49    Curitiba     True    0.0

# %%
# alterar índece

df.index = ['a','b','c','d']

df
# Out:
#        nome  idade      cidade  comprou  saldo
# a    Carlos     35  Araraquara     True    0.0
# b     Pedro     32       Belém    False    0.0
# c   Daniela     15       Natal    False    0.0
# d  Fernanda     49    Curitiba     True    0.0

# %%
df.columns = ['Nome do cliente', 'Idade', 'Cidade', 'Comprou?', 'Saldo']
df
# Out:
#   Nome do cliente  Idade      Cidade  Comprou?  Saldo
# a          Carlos     35  Araraquara      True    0.0
# b           Pedro     32       Belém     False    0.0
# c         Daniela     15       Natal     False    0.0
# d        Fernanda     49    Curitiba      True    0.0

# %% [markdown]
# # Informações Estatísticas

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/drdhenrique/datasets/main/df_rides1.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/drdhenrique/datasets/main/df_rides2.csv")

# %%
df1.shape
# Out:
# (143661, 10)

# %%
df_bikes = pd.concat([df1, df2], axis=0)

# %%
df.shape
# Out:
# (287322, 10)

# %%
df.describe()
# Out:
#        ride_duration      ride_late
# count  214148.000000  214148.000000
# mean       29.915932       0.098829
# std        58.857297       0.298433
# min         3.000000       0.000000
# 25%         8.083333       0.000000
# 50%        14.200000       0.000000
# 75%        33.766667       0.000000
# max       999.600000       1.000000

# %%
round(df.ride_duration.mean(),2)
# Out:
# 29.92

# %%
df.ride_duration.std()
# Out:
# 58.857296541638746

# %% [markdown]
# # Visualizando Dados

# %%
  df_acoes = pd.read_csv("https://raw.githubusercontent.com/drdhenrique/datasets/main/BBAS3.SA.csv", parse_dates = True, index_col = 'Date')

  df_acoes.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-09-19  39.009998  40.380001  38.299999  40.180000  36.829857  15929500
# 2022-09-20  40.299999  40.970001  40.160000  40.790001  37.388992  17350700
# 2022-09-21  40.970001  41.049999  40.270000  40.500000  37.123169  12284500
# 2022-09-22  40.750000  41.430000  40.090000  41.240002  37.801476  14399000
# 2022-09-23  40.799999  40.900002  40.080002  40.730000  37.333992  17071200

# %%
df_acoes.index
# Out:
# DatetimeIndex(['2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22',
#                '2022-09-23', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30',
#                ...
#                '2023-09-01', '2023-09-04', '2023-09-05', '2023-09-06',
#                '2023-09-08', '2023-09-11', '2023-09-12', '2023-09-13',
#                '2023-09-14', '2023-09-15'],
#               dtype='datetime64[ns]', name='Date', length=249, freq=None)

# %%
df_acoes.High.plot(); # ; no final pra suprimir infos extras que saem no plot

# %%
df_acoes.High
# Out:
# Date
# 2022-09-19    40.380001
# 2022-09-20    40.970001
# 2022-09-21    41.049999
# 2022-09-22    41.430000
# 2022-09-23    40.900002
#                 ...
# 2023-09-11    47.540001
# 2023-09-12    47.619999
# 2023-09-13    47.900002
# 2023-09-14    47.919998
# 2023-09-15    47.700001
# Name: High, Length: 249, dtype: float64

# %%
df_acoes.Volume.hist();

# %%
df_acoes.plot.scatter(x = 'Low', y = 'High')
# Out:
# <Axes: xlabel='Low', ylabel='High'>

# %%
df_acoes.High.plot(kind = 'box');

# %% [markdown]
# # Análise Exploratória

# %%
df = pd.read_csv('https://raw.githubusercontent.com/drdhenrique/datasets/main/ocorrencias_aviacao.csv',
            index_col = 'codigo_ocorrencia')

df.head(3)
# Out:
#                   ocorrencia_classificacao  \
# codigo_ocorrencia
# 201305055424986                   ACIDENTE
# 201605160250139            INCIDENTE GRAVE
# 201805021421302                  INCIDENTE
#
#                                                      ocorrencia_tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
#
#                                            ocorrencia_tipo_categoria  \
# codigo_ocorrencia
# 201305055424986                  FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
#
#                   ocorrencia_tipo_icao  ocorrencia_latitude  \
# codigo_ocorrencia
# 201305055424986                 SCF-PP              -9.9085
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5208 entries, 201305055424986 to 201309012098180
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ocorrencia_classificacao        5208 non-null   object
#  1   ocorrencia_tipo                 5208 non-null   object
#  2   ocorrencia_tipo_categoria       5208 non-null   object
#  3   ocorrencia_tipo_icao            5208 non-null   object
#  4   ocorrencia_latitude             5208 non-null   float64
#  5   ocorrencia_longitude            5208 non-null   float64
#  6   ocorrencia_cidade               5208 non-null   object
#  7   ocorrencia_uf                   5208 non-null   object
#  8   ocorrencia_pais                 5208 non-null   object
#  9   ocorrencia_aerodromo            5208 non-null   object
#  10  ocorrencia_dia                  5208 non-null   object
# ...

# %%
df.ocorrencia_tipo.unique()
# Out:
# array(['FALHA DO MOTOR EM VOO',
#        'COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO', 'AERÓDROMO',
#        'POUSO SEM TREM', 'OUTROS', 'PERDA DE CONTROLE NO SOLO',
#        'POUSO LONGO', 'TRÁFEGO AÉREO', 'PERDA DE CONTROLE EM VOO',
#        'COM TREM DE POUSO', 'INDETERMINADO', 'ESTOURO DE PNEU',
#        'VOO CONTROLADO CONTRA O TERRENO', 'EXCURSÃO DE PISTA',
#        'POUSO BRUSCO', 'CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO',
#        'INCURSÃO EM PISTA', 'VAZAMENTO DE OUTROS FLUIDOS', 'COM ROTOR',
#        'FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPONENTE ',
#        'PERDA DE COMPONENTE EM VOO', 'SOPRO DE REATOR',
#        'COM PARA-BRISAS / JANELA / PORTA', 'COM LANÇAMENTO DE CARGA',
#        'POUSO ANTES DA PISTA', 'F.O.D.', 'PROBLEMAS FISIOLÓGICOS',
#        'DESCOMPRESSÃO NÃO INTENCIONAL / EXPLOSIVA',
#        'COLISÃO DE VEÍCULO COM AERONAVE', 'FOGO NO SOLO', 'FOGO EM VOO',
#        'CAUSADO POR FENÔMENO METEOROLÓGICO NO SOLO', 'COM PESSOAL EM VOO',
# ...

# %%
df.tipo.value_counts()
# Out:
# FALHA DO MOTOR EM VOO                             377
# PERDA DE CONTROLE NO SOLO                         325
# PERDA DE CONTROLE EM VOO                          310
# COLISÃO EM VOO COM OBSTÁCULO                      142
# COM TREM DE POUSO                                 130
# OUTROS TIPOS                                       87
# PANE SECA                                          74
# FALHA DE SISTEMA / COMPONENTE                      61
# INDETERMINADA                                      57
# POUSO SEM TREM                                     54
# POUSO EM LOCAL NÃO PREVISTO                        44
# POUSO BRUSCO                                       40
# COLISÃO COM OBSTÁCULO NO SOLO                      40
# POUSO LONGO                                        30
# CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO          27
# PERDA DE COMPONENTE EM VOO                         27
# CFIT - COLISÃO EM VOO CONTROLADO COM O TERRENO     21
# ...

# %%
(df.tipo.value_counts()/df.shape[0]*100).head()
# Out:
# FALHA DO MOTOR EM VOO           18.598915
# PERDA DE CONTROLE NO SOLO       16.033547
# PERDA DE CONTROLE EM VOO        15.293537
# COLISÃO EM VOO COM OBSTÁCULO     7.005427
# COM TREM DE POUSO                6.413419
# Name: tipo, dtype: float64

# %% [markdown]
# ## Loc e iLoc

# %%
df.loc[201305055424986, ['ocorrencia_latitude', 'ocorrencia_longitude']]
# Out:
# ocorrencia_latitude     -9.9085
# ocorrencia_longitude   -63.0333
# Name: 201305055424986, dtype: object

# %%
df.loc[df.ocorrencia_tipo == 'FALHA DO MOTOR EM VOO'].head()
# Out:
#                   ocorrencia_classificacao        ocorrencia_tipo  \
# codigo_ocorrencia
# 201305055424986                   ACIDENTE  FALHA DO MOTOR EM VOO
# 201211159478138                   ACIDENTE  FALHA DO MOTOR EM VOO
# 200811167138358                   ACIDENTE  FALHA DO MOTOR EM VOO
# 201111224132085                   ACIDENTE  FALHA DO MOTOR EM VOO
# 201509183338691                   ACIDENTE  FALHA DO MOTOR EM VOO
#
#                              ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# codigo_ocorrencia
# 201305055424986    FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 201211159478138    FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 200811167138358    FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 201111224132085    FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 201509183338691    FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
#
#                    ocorrencia_latitude  ocorrencia_longitude  \
# ...

# %%
df.iloc[:3,:4]
# Out:
#                   ocorrencia_classificacao  \
# codigo_ocorrencia
# 201305055424986                   ACIDENTE
# 201605160250139            INCIDENTE GRAVE
# 201805021421302                  INCIDENTE
#
#                                                      ocorrencia_tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
#
#                                            ocorrencia_tipo_categoria  \
# codigo_ocorrencia
# 201305055424986                  FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
#
#                   ocorrencia_tipo_icao
# codigo_ocorrencia
# 201305055424986                 SCF-PP
# 201605160250139                   CTOL
# ...

# %% [markdown]
# # Valores Ausentes

# %%
df_bikes.head()
# Out:
#   user_gender user_birthdate user_residence   ride_date time_start  time_end  \
# 0           M     1971-06-08            NaN  2018-01-01   06:05:18  06:21:33
# 1           M     1989-02-11             DF  2018-01-01   06:27:01  06:32:17
# 2           M     1968-07-19            NaN  2018-01-01   06:29:33  06:44:57
# 3           M     1991-12-19            NaN  2018-01-01   06:53:53  06:59:45
# 4           M     1969-03-03             DF  2018-01-01   06:58:56  17:40:04
#
#                      station_start  \
# 0                11 - Rodoviária 2
# 1         26 - Ministério da Saude
# 2                11 - Rodoviária 2
# 3  10 - Ministério dos Transportes
# 4                   15 - Brasil 21
#
#                                          station_end  ride_duration  ride_late
# 0                            41 - Instituto de Artes      16.250000        0.0
# 1  28 - CNMP - Conselho Nacional do Ministério Pú...       5.266667        0.0
# ...

# %%
df_bikes.isnull().sum()
# Out:
# user_gender          396
# user_birthdate         1
# user_residence    179905
# ride_date              0
# time_start             0
# time_end           43285
# station_start          0
# station_end            0
# ride_duration      73174
# ride_late          73174
# dtype: int64

# %%
df_bikes.isnull().sum()/df_bikes.shape[0]*100
# Out:
# user_gender        0.137824
# user_birthdate     0.000348
# user_residence    62.614419
# ride_date          0.000000
# time_start         0.000000
# time_end          15.064979
# station_start      0.000000
# station_end        0.000000
# ride_duration     25.467594
# ride_late         25.467594
# dtype: float64

# %%
df_bikes_rows_drop_na = df_bikes.dropna(subset = ['user_gender'], axis = 0)

# %%
df_bikes_cols_drop_na = df_bikes.dropna(axis = 1)

# %%
df_bikes_rows_drop_na = df_bikes.dropna(axis = 0)

# %%
ride_duration_median = df_bikes.ride_duration.median()

df_bikes.ride_duration.fillna(ride_duration_median, inplace = True)

# %%
df_bikes.user_gender.value_counts()
# Out:
# M    212608
# F     74318
# Name: user_gender, dtype: int64

# %%
df_bikes.user_gender.fillna('M', inplace = True)

df_bikes.user_gender.isnull().sum()
# Out:
# 0
